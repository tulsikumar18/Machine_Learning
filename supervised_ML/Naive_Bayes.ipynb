# %% [markdown]
# # Naive Bayes
#
# ## What is Naive Bayes?
#
# **Naive Bayes** is a **Supervised Machine Learning Algorithm** that is mainly used for **Classification Problems**.
#
# It predicts the class label using **Probability** and is based on **Bayes' Theorem**.
#
# The model assigns the input to the class having the **highest probability**.
#
# ```text
#                Input Data
#                     │
#                     ▼
#           Calculate Probability
#                     │
#                     ▼
#         Compare Class Probabilities
#                     │
#                     ▼
#       Select Highest Probability
#                     │
#                     ▼
#              Predicted Class
# ```
#
# ---
#
# # Why is it called "Naive"?
#
# The word **Naive** means **simple assumption**.
#
# Naive Bayes assumes that **all features are independent of each other**, even though this assumption is usually not true in real-world datasets.
#
# Example
#
# Suppose we want to predict whether a person will buy a laptop.
#
# Features
#
# - Age
# - Salary
# - Occupation
#
# Naive Bayes assumes
#
# ```text
# Age ⟂ Salary ⟂ Occupation
# ```
#
# Each feature contributes independently to the prediction.
#
# ---
#
# # Bayes' Theorem
#
# Naive Bayes is based on **Bayes' Theorem**.
#
# ## Formula
#
# ```text
#              P(B|A) × P(A)
# P(A|B) = -----------------------
#                P(B)
# ```
#
# or
#
# ```text
#              P(X|Y) × P(Y)
# P(Y|X) = -----------------------
#                 P(X)
# ```
#
# Where
#
# - **P(Y|X)** → Posterior Probability
# - **P(X|Y)** → Likelihood
# - **P(Y)** → Prior Probability
# - **P(X)** → Evidence
#
# ---
#
# # Understanding the Formula
#
# Suppose we want to predict whether an email is Spam.
#
# ```text
# P(Spam | Email)
#
# ↓
#
# Probability that the email is Spam
# given the email's words.
# ```
#
# ---
#
# # Components of Bayes Theorem
#
# ## 1. Prior Probability
#
# Probability of an event before seeing any data.
#
# Example
#
# ```text
# Out of 100 emails
#
# 20 are Spam
#
# Prior Probability
#
# P(Spam)
#
# = 20/100
#
# = 0.20
# ```
#
# ---
#
# ## 2. Likelihood
#
# Probability of observing the given features if the class is known.
#
# Example
#
# ```text
# P("Lottery" | Spam)
# ```
#
# Probability that the word **Lottery** appears in Spam emails.
#
# ---
#
# ## 3. Evidence
#
# Overall probability of observing the feature.
#
# Example
#
# ```text
# P("Lottery")
# ```
#
# Probability that the word **Lottery** appears in all emails.
#
# ---
#
# ## 4. Posterior Probability
#
# Final probability after considering the evidence.
#
# Example
#
# ```text
# P(Spam | Lottery)
# ```
#
# Probability that an email is Spam if it contains the word **Lottery**.
#
# ---
#
# # Working of Naive Bayes
#
# ```text
# Training Data
#       │
#       ▼
# Calculate Prior Probability
#       │
#       ▼
# Calculate Likelihood
#       │
#       ▼
# Store Probabilities
#       │
#       ▼
# New Data
#       │
#       ▼
# Apply Bayes Theorem
#       │
#       ▼
# Calculate Probability of Every Class
#       │
#       ▼
# Choose Highest Probability
#       │
#       ▼
# Prediction
# ```
#
# ---
#
# # Example
#
# Training Data
#
# | Weather | Play |
# |----------|------|
# | Sunny | Yes |
# | Rainy | No |
# | Sunny | Yes |
# | Cloudy | Yes |
# | Rainy | No |
#
# Suppose
#
# New Weather = Sunny
#
# The model calculates
#
# ```text
# P(Yes | Sunny)
#
# and
#
# P(No | Sunny)
# ```
#
# Whichever probability is higher becomes the prediction.
#
# ---
#
# # Types of Naive Bayes
#
# There are **three major types**.
#
# ```text
#               Naive Bayes
#                    │
#       ┌────────────┼─────────────┐
#       │            │             │
#       ▼            ▼             ▼
#  Gaussian     Multinomial    Bernoulli
# ```
#
# ---
#
# # 1. Gaussian Naive Bayes
#
# Used when the input features are **Continuous Numerical Data**.
#
# It assumes the data follows a **Normal (Gaussian) Distribution**.
#
# Examples
#
# - Height
# - Weight
# - Salary
# - Age
# - Temperature
#
# ```text
#           Bell Curve
#
#               ▲
#              ▲ ▲
#             ▲   ▲
#           ▲       ▲
#         ▲           ▲
# ──────▲──────────────▲──────
# ```
#
# ### Import
#
# ```python
# from sklearn.naive_bayes import GaussianNB
# ```
#
# ---
#
# # 2. Multinomial Naive Bayes
#
# Used when features represent **Counts or Frequencies**.
#
# Mostly used for **Text Classification**.
#
# Examples
#
# - Count Vectorizer
# - TF-IDF
# - Word Frequency
#
# Applications
#
# - Spam Detection
# - Sentiment Analysis
# - News Classification
#
# ### Import
#
# ```python
# from sklearn.naive_bayes import MultinomialNB
# ```
#
# ---
#
# # 3. Bernoulli Naive Bayes
#
# Used when input features contain only
#
# - 0
# - 1
#
# (Binary Features)
#
# Examples
#
# ```text
# Contains Link?
#
# Yes = 1
#
# No = 0
# ```
#
# ```text
# Contains Offer?
#
# Yes = 1
#
# No = 0
# ```
#
# Mostly used after
#
# - Binary Count Vectorizer
# - Binary Features
#
# Applications
#
# - Spam Detection
# - Email Classification
#
# ### Import
#
# ```python
# from sklearn.naive_bayes import BernoulliNB
# ```
#
# ---
#
# # Which Naive Bayes Should We Use?
#
# | Data Type | Algorithm |
# |------------|-----------|
# | Continuous Numerical Data | GaussianNB |
# | Word Frequency | MultinomialNB |
# | Binary Features (0/1) | BernoulliNB |
#
# ---
#
# # Real-Life Applications
#
# - Spam Detection
# - Email Classification
# - Sentiment Analysis
# - Fake News Detection
# - Document Classification
# - Language Detection
# - Medical Diagnosis
# - Recommendation Systems
#
# ---
#
# # Advantages
#
# - Very fast
# - Simple to understand
# - Easy to implement
# - Works well on small datasets
# - Requires less training time
# - Works well for text classification
# - Performs well with high-dimensional data
#
# ---
#
# # Disadvantages
#
# - Assumes features are independent
# - Cannot learn complex relationships
# - Sensitive to correlated features
# - Performance decreases if assumptions are violated
# - Not suitable for highly complex datasets
#
# ---
#
# # Why is Naive Bayes popular for NLP?
#
# Text datasets usually contain
#
# - Thousands of words
# - High-dimensional features
#
# Naive Bayes handles such data efficiently.
#
# It is commonly used with
#
# - Count Vectorizer
# - TF-IDF Vectorizer
#
# Applications
#
# - Spam Detection
# - Movie Review Classification
# - Email Filtering
#
# ---
#
# # Workflow in NLP
#
# ```text
# Text Data
#      │
#      ▼
# Cleaning
# (Remove Stopwords, Punctuation)
#      │
#      ▼
# Vectorization
# (Count Vectorizer / TF-IDF)
#      │
#      ▼
# Naive Bayes
#      │
#      ▼
# Prediction
# ```
#
# ---
#
# # Comparison of Naive Bayes Types
#
# | Algorithm | Data Type | Example |
# |------------|-----------|----------|
# | GaussianNB | Continuous Numerical Data | Salary, Height |
# | MultinomialNB | Count/Frequency Data | Count Vectorizer, TF-IDF |
# | BernoulliNB | Binary Data (0/1) | Spam Features |
#
# ---
#
# # Syntax
#
# ```python
# from sklearn.naive_bayes import GaussianNB
# from sklearn.naive_bayes import MultinomialNB
# from sklearn.naive_bayes import BernoulliNB
# ```
#
# Gaussian
#
# ```python
# model = GaussianNB()
# ```
#
# Multinomial
#
# ```python
# model = MultinomialNB()
# ```
#
# Bernoulli
#
# ```python
# model = BernoulliNB()
# ```
#
# ---
#
# # Complete Workflow
#
# ```text
# Dataset
#    │
#    ▼
# Train-Test Split
#    │
#    ▼
# Feature Engineering
# (Vectorization if text)
#    │
#    ▼
# Choose Naive Bayes Type
#    │
#    ▼
# Train Model
#    │
#    ▼
# Prediction
#    │
#    ▼
# Evaluation
# (Accuracy, Precision, Recall, F1-score)
# ```
#
# ---
#
# # Important Interview Questions
#
# ### 1. What is Naive Bayes?
#
# A supervised machine learning algorithm used for classification based on probability and Bayes' Theorem.
#
# ---
#
# ### 2. Why is it called Naive?
#
# Because it assumes that all input features are independent of each other.
#
# ---
#
# ### 3. What is Bayes' Theorem?
#
# ```text
#              P(B|A) × P(A)
# P(A|B) = -----------------------
#                P(B)
# ```
#
# ---
#
# ### 4. Which Naive Bayes algorithm is used for numerical data?
#
# **Gaussian Naive Bayes**
#
# ---
#
# ### 5. Which Naive Bayes algorithm is used with Count Vectorizer or TF-IDF?
#
# **Multinomial Naive Bayes**
#
# ---
#
# ### 6. Which Naive Bayes algorithm is used for binary (0/1) features?
#
# **Bernoulli Naive Bayes**
#
# ---
#
# ### 7. Why is Naive Bayes widely used in NLP?
#
# Because it is fast, handles high-dimensional text data efficiently, and performs well for text classification tasks.
#
# ---
#
# ### 8. Name some applications of Naive Bayes.
#
# - Spam Detection
# - Email Classification
# - Sentiment Analysis
# - Fake News Detection
# - Document Classification
# - Language Detection
#
# ---
#
# # Key Points to Remember
#
# - Supervised Learning Algorithm.
# - Used mainly for **Classification**.
# - Based on **Bayes' Theorem**.
# - Uses **Probability** to predict the class.
# - Chooses the class with the **highest probability**.
# - Assumes all features are **independent** (Naive assumption).
# - Three main types:
#   - **GaussianNB** → Continuous numerical data.
#   - **MultinomialNB** → Count/Frequency data (Count Vectorizer, TF-IDF).
#   - **BernoulliNB** → Binary (0/1) data.
# - Commonly used in **Spam Detection**, **Email Classification**, and **Sentiment Analysis**.
# ```

# %%
# ============================================================
# Import Required Libraries
# ============================================================

import pandas as pd

# Import Multinomial Naive Bayes classifier
from sklearn.naive_bayes import MultinomialNB

# Split dataset into training and testing sets
from sklearn.model_selection import train_test_split

# Pipeline helps combine preprocessing and model into one object
from sklearn.pipeline import Pipeline

# Used to evaluate model performance
from sklearn.metrics import classification_report

# Converts text into numerical features using TF-IDF
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# ============================================================
# Load Dataset
# ============================================================

# Read the IMDB movie review dataset
df = pd.read_csv("../datasets/IMDB Dataset.csv")

# Display first 5 rows
print(df.head())
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
# ============================================================
# Separate Features and Target
# ============================================================

# Input Feature (Movie Reviews)
X = df["review"]

# Target Column (positive / negative)
y = df["sentiment"]

# %%
# ============================================================
# Train-Test Split
# ============================================================

# 80% Training Data
# 20% Testing Data

xtrain, xtest, ytrain, ytest = train_test_split(
    X,
    y,
    train_size=0.80,
    random_state=42
)

# %%
# ============================================================
# Create Machine Learning Pipeline
# ============================================================

# Step 1 : Convert text into TF-IDF vectors
# Step 2 : Train Multinomial Naive Bayes

main_pipeline = Pipeline(

    steps=[

        ("vectorizer", TfidfVectorizer()),

        ("model", MultinomialNB())

    ]

)

# %%
# ============================================================
# Train the Model
# ============================================================

main_pipeline.fit(xtrain, ytrain)


# ============================================================
# Predictions
# ============================================================

# Prediction on Training Data
ytrain_pred = main_pipeline.predict(xtrain)

# Prediction on Testing Data
ytest_pred = main_pipeline.predict(xtest)

# %%
# ============================================================
# Model Evaluation
# ============================================================

print("Training Classification Report")
print(classification_report(ytrain, ytrain_pred))
# Out:
# Training Classification Report
#               precision    recall  f1-score   support
#
#     negative       0.88      0.92      0.90     20039
#     positive       0.92      0.88      0.90     19961
#
#     accuracy                           0.90     40000
#    macro avg       0.90      0.90      0.90     40000
# weighted avg       0.90      0.90      0.90     40000

# %%
print("Testing Classification Report")
print(classification_report(ytest, ytest_pred))
# Out:
# Testing Classification Report
#               precision    recall  f1-score   support
#
#     negative       0.84      0.89      0.87      4961
#     positive       0.88      0.84      0.86      5039
#
#     accuracy                           0.86     10000
#    macro avg       0.86      0.86      0.86     10000
# weighted avg       0.86      0.86      0.86     10000

# %%
# ============================================================
# Conclusion
# ============================================================

# If the training and testing accuracy are both high
# and their values are close to each other,
# then the model is considered a Good Fit.

# If training accuracy is much higher than testing accuracy,
# then the model is Overfitting.

# If both training and testing accuracies are low,
# then the model is Underfitting.

# %% [markdown]
# ## REsearch about these models , STT , fast whisper-large-v2(openAI)
# *

# %% [markdown]
# ## Spam data and classify whether the model is overfit or underfit or good fit..

# %%
import pandas as pd
from sklearn.naive_bayes import BernoulliNB
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = pd.read_csv('../datasets/spam.csv')
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
X = df['v2']
y = df['v1']

# %%
xtrain,xtest,ytrain,ytest = train_test_split(X,y,train_size=0.8, random_state=42)

# %%
pipeline = Pipeline(

    steps=[
            ('vectorizer', TfidfVectorizer()),
            ('model', BernoulliNB())
    ]
)

# %%
pipeline.fit(xtrain,ytrain)
# Out:
# Pipeline(steps=[('vectorizer', TfidfVectorizer()), ('model', BernoulliNB())])

# %%
# Prediction on Training Data
ytrain_pred = pipeline.predict(xtrain)

# Prediction on Testing Data
ytest_pred = pipeline.predict(xtest)

# %%
print("Training Classification Report")
print(classification_report(ytrain, ytrain_pred))
# Out:
# Training Classification Report
#               precision    recall  f1-score   support
#
#          ham       0.99      1.00      0.99      3860
#         spam       0.99      0.91      0.95       597
#
#     accuracy                           0.99      4457
#    macro avg       0.99      0.96      0.97      4457
# weighted avg       0.99      0.99      0.99      4457

# %%
print("Testing Classification Report")
print(classification_report(ytest, ytest_pred))
# Out:
# Testing Classification Report
#               precision    recall  f1-score   support
#
#          ham       0.97      1.00      0.99       965
#         spam       1.00      0.81      0.90       150
#
#     accuracy                           0.97      1115
#    macro avg       0.99      0.91      0.94      1115
# weighted avg       0.98      0.97      0.97      1115
