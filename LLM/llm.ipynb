# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm_model = ChatGoogleGenerativeAI(

    model  = 'gemini-3.5-flash',
    api_key = 'AIzaSyD33uTKSDhBzTeTMyr9HPYPHaR5IeNLF7c'
)

# %%
response = llm_model.invoke('Explain Linear Regression...')

# %%
print(response.content[0]['text'])
# Out:
# At its core, **Linear Regression** is one of the simplest and most popular algorithms in statistics and machine learning. It is used to predict a continuous outcome (like price, temperature, or sales) based on one or more predictor variables.
#
# Imagine you want to predict a student's exam score based on how many hours they studied. Linear regression helps you find the direct relationship between "Hours Studied" and "Exam Score."
#
# Here is a step-by-step breakdown of how it works.
#
# ---
#
# ### 1. The Core Idea: The Line of Best Fit
# If you plot your data on a graph (e.g., Study Hours on the X-axis and Exam Scores on the Y-axis), you will get a scatter plot of dots.
#
# Linear regression tries to draw a **straight line** through those dots that fits the data as closely as possible. This is called the **line of best fit**.
#
# Once you have this line, you can use it to make predictions. For example, "If a student studies for 6 hours, what score does the line predict?"
#
# ---
#
# ### 2. The Math Behind the Line
# The line is represented by a simple algebraic equation:
#
# $$Y = \beta_0 + \beta_1X$$
#
# *   **$Y$ (Dependent Variable):** The thing you are trying to predict (e.g., Exam Score).
# *   **$X$ (Independent Variable):** The input you are using to make the prediction (e.g., Study Hours).
# *   **$\beta_0$ (Y-intercept):** The starting point. It is the value of $Y$ when $X$ is zero (e.g., the score a student gets if they study for 0 hours).
# *   **$\beta_1$ (Slope/Coefficient):** The steepness of the line. It tells you how much $Y$ changes for every one-unit increase in $X$ (e.g., how many extra exam points you get for each additional hour of study).
#
# ---
#
# ### 3. How Does the Algorithm Find the "Best" Line?
# The algorithm doesn't just guess the line; it calculates it mathematically using a method called **Ordinary Least Squares (OLS)**.
#
# 1.  **Calculate the Error (Residual):** For any data point, the "error" is the distance between the actual data point and the predicted line.
# 2.  **Square the Errors:** We square these distances (so negative errors don't cancel out positive ones, and bigger errors are penalized more).
# 3.  **Minimize the Sum:** The algorithm adjusts the slope ($\beta_1$) and intercept ($\beta_0$) until the **Sum of Squared Errors (SSE)** is as small as possible.
#
# ---
#
# ### 4. Types of Linear Regression
# *   **Simple Linear Regression:** Using **one** independent variable to predict the outcome.
#     *   *Example:* Predicting house price ($Y$) based *only* on square footage ($X$).
# *   **Multiple Linear Regression:** Using **two or more** independent variables to predict the outcome.
#     *   *Example:* Predicting house price ($Y$) based on square footage ($X_1$), number of bedrooms ($X_2$), and age of the house ($X_3$).
#     *   *Equation:* $Y = \beta_0 + \beta_1X_1 + \beta_2X_2 + ... + \beta_nX_n$
#
# ---
#
# ### 5. How to Tell if Your Model is Good?
# Once you build a linear regression model, you need to evaluate it. Two common metrics are:
#
# 1.  **$R$-Squared ($R^2$):** This measures how much of the variation in $Y$ can be explained by $X$. It ranges from 0 to 1 (or 0% to 100%). An $R^2$ of 0.85 means your model explains 85% of the variation in the data.
# 2.  **RMSE (Root Mean Squared Error):** This measures the average distance between the actual values and the predicted values. Lower RMSE means better predictions.
#
# ---
#
# ### 6. The Assumptions of Linear Regression
# For linear regression to work accurately, your data must meet a few rules:
# *   **Linearity:** The relationship between $X$ and $Y$ must be a straight line (not a curve).
# *   **Independence:** The data points must be independent of each other.
# *   **Homoscedasticity:** The prediction errors (residuals) should be roughly equal across all levels of $X$.
# *   **Normality:** The errors should be normally distributed (bell-curved).
#
# ---
#
# ### Pros and Cons
#
# **Pros:**
# *   **Simple and Fast:** Easy to understand, explain, and compute.
# *   **Highly Interpretable:** You can look at the coefficients ($\beta_1$) and say exactly how important each variable is.
#
# **Cons:**
# *   **Too Simple for Real Life:** Real-world relationships are rarely perfectly straight lines.
# *   **Sensitive to Outliers:** A single extreme data point can wildly throw off the line of best fit.
